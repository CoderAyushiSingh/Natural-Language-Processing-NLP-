# %% [markdown]
# #Useful NLP Libraries & Networks | Assignment

# %% [markdown]
# #Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.
#
# - Comparison between NLTK and spaCy
# 1. Features
#
#   - NLTK
#
#       - Provides a wide range of NLP tools and algorithms.
#
#       - Includes many linguistic datasets and corpora like WordNet.
#
#   - spaCy
#
#       - Provides advanced NLP features with pre-trained models.
#
#       - Supports tokenization, POS tagging, Named Entity Recognition (NER), and dependency parsing.
#
# 2. Ease of Use
#
#   - NLTK
#
#      - Requires multiple steps for performing NLP tasks.
#
#     - Needs manual downloading of datasets.
#   - spaCy
#
#       - Easy-to-use pipeline-based architecture.
#
#       - Simple installation and implementation.
# 3. Performance
#
#   - NLTK
#
#       - Slower in processing large datasets.
#
#        - Written mainly in Python.
#   - spaCy
#
#      - Much faster due to Cython optimization.
#
#      - Efficient for large-scale text processing.
# 4. Use Cases
#
#   - NLTK
#
#      - Academic learning and research.
#
#      - Teaching NLP fundamentals.
#  - spaCy
#
#     - Chatbots and AI applications.
#
#     - Information extraction and text analytics.
#
# #Question 2: What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation?
#
#
# - TextBlob is a Python library used for simple Natural Language Processing (NLP) tasks.
#
# - It is built on top of NLTK and Pattern libraries.
#
# - It provides an easy interface for performing common text-processing operations.
#
# - Mainly used by beginners for quick NLP implementation.
#
#
# **TextBlob Simplifies NLP Tasks**
#
# 1. Sentiment Analysis
#
#    - TextBlob automatically analyzes the sentiment of text.
#    - No need to train a machine learning model manually.
# 2. Translation
#
#     - TextBlob provides built-in text translation functionality.
#
#     - It can translate text from one language to another easily.
# 3. Other NLP Tasks Supported
#
#     - Tokenization (breaking text into words/sentences)
#
#     - Part-of-Speech (POS) tagging
#
# #Question 3: Explain the role of Standford NLP in academic and industry NLP Projects.
#
# - Stanford NLP is a collection of Natural Language Processing tools developed by Stanford University.
#
#  - It provides advanced NLP libraries such as Stanford CoreNLP and Stanza.
#
# - Designed for accurate linguistic analysis and research-level NLP tasks.
#
# **1. Role in Academic NLP Projects**
#
#    - Widely used in research and educational institutions.
#
#    - Helps students understand linguistic structures of language.
#    - Used for developing and testing new NLP algorithms.
#
#    - Provides highly accurate syntactic and semantic analysis useful for research papers.
#
# **2. Role in Industry NLP Projects**
#
#    - Used in real-world applications requiring deep text understanding.
#
#    - Applied in:
#
#         - Chatbots and virtual assistants
#
#         - Information extraction systems
#
#         - Sentiment analysis platforms
#
#         - Document and content analysis
#
#   - Helps organizations process large volumes of textual data efficiently.
#
#   - Suitable for enterprise-level NLP solutions.
#
# **3. Key Features Supporting Both Domains**
#
#    - High accuracy linguistic models.
#
#    - Multi-language support.
#
#    - Pre-trained NLP models.
#
# #Question 4: Describe the architecture and functioning of a Recurrent Natural Network (RNN).
#
# **Recurrent Neural Network (RNN)**
#
#    - A Recurrent Neural Network (RNN) is a type of neural network designed to process sequential data.
#
#    - It remembers previous inputs using an internal memory.
#
#    - Commonly used in tasks like text prediction, speech recognition, and language modeling.
#
# **Architecture of RNN**
#
#   - An RNN consists of:
#
#       - Input Layer → receives sequential data (words, time-series values).
#
#       - Hidden Layer → stores information from previous time steps.
#
#       - Output Layer → produces prediction/output.
#
#   - Unlike traditional neural networks, the hidden layer has a feedback connection, meaning:
#
#      - Output from the previous step is fed back into the network.
#
#      - This creates a loop structure.
#
# **Working / Functioning of RNN**
#
#    - Input sequence is given one element at a time.
#
#    - The network processes the current input along with information from the previous hidden state.
#
#    - Hidden state updates its memory using:
#
#       - Current input
#
#       - Previous hidden state
# #Question 5: What is the key difference between LSTM and GRU networks in NLP applications?
#
# - Definition
#
# 1. LSTM (Long Short-Term Memory)
#
#    - A special type of RNN designed to learn long-term dependencies using multiple memory gates.
#
# 2. GRU (Gated Recurrent Unit)
#
#    - A simplified version of LSTM that combines some gates to make computation faster.
#
# -  Structure Difference
#
# 1. LSTM
#
#       - Contains three gates:
#
#       - Input Gate
#
#       - Forget Gate
#
#       - Output Gate
# 2. GRU
#
#      - Contains two gates:
#
#      - Update Gate
#
#      - Reset Gate
# - Complexity
#
# 1.  LSTM
#
#     - More complex architecture.
#
#     - Higher number of parameters.
#
#      - Requires more training time.
#
# 2. GRU
#
#      - Simpler architecture.
#
#      - Fewer parameters.
#
#      - Faster training.

# %% [markdown]
# #Question 6: Write a Python program using TextBlob to perform sentiment analysis on the following paragraph of text:
# **“I had a great experience using the new mobile banking app. The interface is intuitive,
# and customer support was quick to resolve my issue. However, the app did crash once
# during a transaction, which was frustrating"**
# Your program should print out the polarity and subjectivity scores.

# %%
from textblob import TextBlob

text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating."""

blob = TextBlob(text)

sentiment = blob.sentiment

print("Polarity Score:", sentiment.polarity)
print("Subjectivity Score:", sentiment.subjectivity)
# Out:
# Polarity Score: 0.21742424242424244
# Subjectivity Score: 0.6511363636363636

# %% [markdown]
# #Question 7: Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK:
# **“Natural Language Processing (NLP) is a fascinating field that combines linguistics,
# computer science, and artificial intelligence. It enables machines to understand,
# interpret, and generate human language. Applications of NLP include chatbots,
# sentiment analysis, and machine translation. As technology advances, the role of NLP
# in modern solutions is becoming increasingly critical.”**

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')

text = """Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language. Applications of NLP include chatbots,
sentiment analysis, and machine translation. As technology advances, the role of NLP
in modern solutions is becoming increasingly critical."""

tokens = word_tokenize(text)

words = [word.lower() for word in tokens if word.isalpha()]

freq_dist = FreqDist(words)

print("Tokens:")
print(words)

print("\nWord Frequency Distribution:")
for word, frequency in freq_dist.items():
    print(word, ":", frequency)
# Out:
# Tokens:
# ['natural', 'language', 'processing', 'nlp', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', 'computer', 'science', 'and', 'artificial', 'intelligence', 'it', 'enables', 'machines', 'to', 'understand', 'interpret', 'and', 'generate', 'human', 'language', 'applications', 'of', 'nlp', 'include', 'chatbots', 'sentiment', 'analysis', 'and', 'machine', 'translation', 'as', 'technology', 'advances', 'the', 'role', 'of', 'nlp', 'in', 'modern', 'solutions', 'is', 'becoming', 'increasingly', 'critical']
#
# Word Frequency Distribution:
# natural : 1
# language : 2
# processing : 1
# nlp : 3
# is : 2
# a : 1
# fascinating : 1
# field : 1
# that : 1
# combines : 1
# linguistics : 1
# computer : 1
# science : 1
# and : 3
# artificial : 1
# intelligence : 1
# it : 1
# enables : 1
# machines : 1
# to : 1
# understand : 1
# interpret : 1
# generate : 1
# human : 1
# applications : 1
# of : 2
# include : 1
# chatbots : 1
# sentiment : 1
# analysis : 1
# machine : 1
# ...

# %% [markdown]
# #Question 8: Implement a basic LSTM model in Keras for a text classification task using the following dummy dataset. Your model should classify sentences as either positive (1) or negative (0).
# # Dataset
# **texts = [
# “I love this project”, #Positive
# “This is an amazing experience”, #Positive
# “I hate waiting in line”, #Negative
# “This is the worst service”, #Negative
# “Absolutely fantastic!” #Positive
# ]
# labels = [1, 1, 0, 0, 1]
# Preprocess the text, tokenize it, pad sequences, and build an LSTM model to train on
# this data. You may use Keras with TensorFlow backend.**

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

max_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

labels = np.array(labels)

vocab_size = len(tokenizer.word_index) + 1

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=16, input_length=max_length),
    LSTM(32),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(padded_sequences, labels, epochs=20, verbose=1)

test_text = ["I really love this service"]
test_seq = tokenizer.texts_to_sequences(test_text)
test_pad = pad_sequences(test_seq, maxlen=max_length, padding='post')

prediction = model.predict(test_pad)

print("Prediction Score:", prediction[0][0])
print("Sentiment:", "Positive" if prediction[0][0] > 0.5 else "Negative")
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 1.0000 - loss: 0.6920
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8000 - loss: 0.6904
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6000 - loss: 0.6887
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6000 - loss: 0.6871
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6000 - loss: 0.6854
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6000 - loss: 0.6837
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6000 - loss: 0.6820
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6000 - loss: 0.6802
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6000 - loss: 0.6783
# Epoch 10/20
# ...

# %% [markdown]
# #Question 9: Using spaCy, build a simple NLP pipeline that includes tokenization, lemmatization, and entity recognition. Use the following paragraph as your dataset:
# **“Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
# development of India’s atomic energy program. He was the founding director of the Tata
# Institute of Fundamental Research (TIFR) and was instrumental in establishing the
# Atomic Energy Commission of India.”**
#
# Write a Python program that processes this text using spaCy, then prints tokens, their
# lemmas, and any named entities found.

# %%
# !pip install spacy

# !python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load("en_core_web_sm")

text = """Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role in the
development of India’s atomic energy program. He was the founding director of the Tata
Institute of Fundamental Research (TIFR) and was instrumental in establishing the
Atomic Energy Commission of India."""

doc = nlp(text)

print("Tokens and Lemmas:\n")
for token in doc:
    print(f"Token: {token.text}  |  Lemma: {token.lemma_}")

print("\nNamed Entities:\n")
for ent in doc.ents:
    print(f"Entity: {ent.text}  |  Label: {ent.label_}")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 83.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Tokens and Lemmas:
#
# Token: Homi  |  Lemma: Homi
# Token: Jehangir  |  Lemma: Jehangir
# Token: Bhaba  |  Lemma: Bhaba
# Token: was  |  Lemma: be
# Token: an  |  Lemma: an
# Token: Indian  |  Lemma: indian
# Token: nuclear  |  Lemma: nuclear
# Token: physicist  |  Lemma: physicist
# Token: who  |  Lemma: who
# Token: played  |  Lemma: play
# Token: a  |  Lemma: a
# Token: key  |  Lemma: key
# Token: role  |  Lemma: role
# Token: in  |  Lemma: in
# Token: the  |  Lemma: the
# Token:
#   |  Lemma:
#
# Token: development  |  Lemma: development
# ...

# %% [markdown]
# #Question 10: You are working on a chatbot for a mental health platform. Explain how you would leverage LSTM or GRU networks along with libraries like spaCy or Stanford NLP to understand and respond to user input effectively. Detail your architecture, data preprocessing pipeline, and any ethical considerations.

# %% [markdown]
# - Mental Health Chatbot using LSTM/GRU and NLP Libraries
# 1. Architecture
#
#     - User input is processed using spaCy or Stanford CoreNLP.
#
#     - Perform tokenization, lemmatization, and entity recognition.
#
#     - Convert text into numerical sequences (word embeddings).
#
#     - Pass sequences to LSTM or GRU model.
#
#     - Model predicts user emotion or intent.
#
#     - Chatbot generates an appropriate response.
#
# 2. Data Preprocessing Pipeline
#
#     - Text cleaning (lowercase, remove noise)
#
#     - Tokenization and lemmatization
#
#     - Convert text to sequences
#
#     - Padding and embedding generation
#
# 3. Role of LSTM / GRU
#
#     - LSTM: Captures long conversation context.
#
#     - GRU: Faster and suitable for real-time responses.
#
# 4. Ethical Considerations
#
#     - Protect user privacy and data.
#
#     - Detect crisis or self-harm messages.
#
#     - Avoid biased or harmful responses.
#
#     - Escalate serious cases to human professionals.
